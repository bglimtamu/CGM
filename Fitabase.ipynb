# %%
import pandas as pd

# 엑셀 파일 불러오기

# %%
import pandas as pd

# CSV 파일 불러오기
df = pd.read_csv('/Users/bg.lim/Downloads/Texas A&M_Agrilife/Projects/1.CGM/Pilot/Datas/FIT/FITABASE_ALLMERGED.csv')  # 파일 경로 지정

df
# Out:
# /var/folders/r0/h30ywvr55x98xwjf49klh76m0000gp/T/ipykernel_75031/912269815.py:4: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/bg.lim/Downloads/Texas A&M_Agrilife/Projects/1.CGM/Pilot/Datas/FIT/FITABASE_ALLMERGED.csv')  # 파일 경로 지정
#             Id                   Time  Intensity        Date  Steps  \
# 0        CGM01  06OCT2022:23:05:00.00          0  10/06/2022      0
# 1        CGM01  08OCT2022:01:36:00.00          0  10/08/2022      0
# 2        CGM01  08OCT2022:23:24:00.00          0  10/08/2022      0
# 3        CGM01  10OCT2022:00:00:30.00          1  10/10/2022      0
# 4        CGM01  10OCT2022:23:18:30.00          0  10/10/2022      0
# ...        ...                    ...        ...         ...    ...
# 1367614  CGM89  09MAY2023:23:55:00.00          0  05/09/2023      0
# 1367615  CGM89  09MAY2023:23:56:00.00          0  05/09/2023      0
# ...

# %%
print(df.columns)
# Out:
# Index(['Id', 'Time', 'Intensity', 'Date', 'Steps', 'TotalSleepRecords',
#        'TotalMinutesAsleep', 'TotalTimeInBed', 'TotalTimeAwake',
#        'TotalMinutesLight', 'TotalMinutesDeep', 'TotalMinutesREM', 'LogId',
#        'Duration', 'Efficiency', 'IsMainSleep', 'SleepDataType',
#        'MinutesAfterWakeUp', 'MinutesAsleep', 'MinutesToFallAsleep',
#        'TimeInBed', 'ClassicAsleepCount', 'ClassicAsleepDuration',
#        'ClassicAwakeCount', 'ClassicAwakeDuration', 'ClassicRestlessCount',
#        'ClassicRestlessDuration', 'StagesWakeCount', 'StagesWakeDuration',
#        'StagesWakeThirtyDayAvg', 'StagesLightCount', 'StagesLightDuration',
#        'StagesLightThirtyDayAvg', 'StagesDeepCount', 'StagesDeepDuration',
#        'StagesDeepThirtyDayAvg', 'StagesREMCount', 'StagesREMDuration',
#        'StagesREMThirtyDayAvg', 'SleepLogType'],
#       dtype='object')

# %%
# Display 10 random rows from the DataFrame
df_random = df.sample(n=20, random_state=42)  # Set random_state for reproducibility
df_random
# Out:
#             Id                   Time  Intensity        Date  Steps  \
# 872651   CGM57  08MAR2023:05:26:00.00          0  03/08/2023      0
# 497759   CGM32  05DEC2022:21:14:00.00          0  12/05/2022      0
# 762465   CGM49  26FEB2023:17:00:00.00          0  02/26/2023      0
# 117941   CGM10  31OCT2022:21:41:00.00          0  10/31/2022      0
# 476975   CGM31  29NOV2022:10:50:00.00          0  11/29/2022      0
# 431045   CGM28  29NOV2022:13:20:00.00          1  11/29/2022     70
# 1198890  CGM78  11APR2023:18:45:00.00          1  04/11/2023      8
# 1267963  CGM83  16APR2023:14:30:00.00          0  04/16/2023      0
# 21677    CGM02  13OCT2022:01:17:00.00          0  10/13/2022      0
# 1060241  CGM70  23MAR2023:11:56:00.00          0  03/23/2023      0
# 1182134  CGM77  11APR2023:03:29:00.00          0  04/11/2023      0
# 567780   CGM39  07DEC2022:12:15:00.00          0  12/07/2022      0
# 777613   CGM50  24FEB2023:05:28:00.00          0  02/24/2023      0
# ...
